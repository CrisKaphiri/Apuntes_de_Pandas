# %%
import pandas as pd

# %%
#df.rename(columns={'points' : 'score'}) - Renombrar una columna
#df.rename(index= {0: 'primer_indice', 1: 'segundo_indice'}) - Renombrar indices
#df.rename_axis("wines", axis='rows').rename_axis("fields", axis= 'columns')

#pd.concat([df1, df2]) - Combina ambos dataframes, deben tener las mismas columnas
